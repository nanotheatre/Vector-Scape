# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; flex-direction: column; position: relative;"><div style="display: flex; justify-content: center; flex-wrap: wrap; align-items: stretch; width: 620px; margin: 0 auto; padding: 10px 6px 6px; background: #e2e2e2; box-shadow: 10px 10px 5px #fff inset,-10px -10px 5px #fff inset;"><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-22" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-22-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-10" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-10-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-5b" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-5b-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-16" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-16-300x.png"></a></div><div style="margin: 20px; "><a href="Polyptych-11.ipynb"><svg xmlns="http://www.w3.org/2000/svg" width="45" height="45" fill="gray" class="bi bi-chevron-left" viewBox="0 0 16 16"><path fill-rule="evenodd" d="M11.354 1.646a.5.5 0 0 1 0 .708L5.707 8l5.647 5.646a.5.5 0 0 1-.708.708l-6-6a.5.5 0 0 1 0-.708l6-6a.5.5 0 0 1 .708 0"></path></svg></a><a href="Polyptych-02.ipynb"><svg xmlns="http://www.w3.org/2000/svg" width="45" height="45" fill="gray" class="bi bi-chevron-right" viewBox="0 0 16 16"><path fill-rule="evenodd" d="M4.646 1.646a.5.5 0 0 1 .708 0l6 6a.5.5 0 0 1 0 .708l-6 6a.5.5 0 0 1-.708-.708L10.293 8 4.646 2.354a.5.5 0 0 1 0-.708"></path></svg></a></div></div>
