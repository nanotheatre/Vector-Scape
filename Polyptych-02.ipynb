# %% [markdown]
# <div style="display: flex; justify-content: center; position: relative;"><div style="display: flex; justify-content: center; flex-wrap: wrap; align-items: stretch; width: 620px; margin: 0 auto; padding: 10px 6px 6px; background: #e2e2e2; box-shadow: 10px 10px 5px #fff inset,-10px -10px 5px #fff inset;"><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-17" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-17-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=22-07-2022-2" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/22-07-2022-2-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-6" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-6-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-15" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-15-300x.png"></a></div></div>
