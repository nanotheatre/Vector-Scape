# %% [markdown]
# <div style="background-image: linear-gradient(90deg, #f5f5f500 0 6%, #f5f5f5 10% 96%, #f5f5f500 99% 100%); display: flex; justify-content: center; position: relative; left: -50px;"><div style="display: flex; justify-content: start; flex-wrap: wrap; width: 625px; margin: 0 auto; padding: 3px 5px 0;"><a href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-24"><img style="border: 1px solid #ccc; margin: 0 2px; min-width: 300px; max-width: 300px;" src="https://github.com/nanotheatre/Vectorscapes/main/300x/15-08-2020-24-300x.pnghttps://github.com/nanotheatre/nanotheatre.github.io/blob/master/Vector-Space/300x/00-00-0000-3-300x.png?raw=true" /></a><a href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-22"><img style="border: 1px solid #ccc; margin: 0 2px; min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-22-300x.png" /></a><a href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-10"><img style="border: 1px solid #ccc; margin: 0 2px; min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-10-300x.png" /></a><a href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-5b"><img style="border: 1px solid #ccc; margin: 0 2px; min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-5b-300x.png" /></a></div></div>
